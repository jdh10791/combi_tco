# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pymatgen as mg
import ternary

# %%
datadir = os.path.join(os.environ['HOME'],'OneDrive - Colorado School of Mines\\Research\\MIDDMI\\TCO\\Data')
count = 'processed'
scriptdir = os.path.join(os.environ['HOME'],'OneDrive - Colorado School of Mines\\Research\\MIDDMI\\TCO\\scripts')
cntdir = os.path.join(datadir,count)
os.chdir(cntdir)

# %%
os.chdir(cntdir)
#prefix = 'PDAC_COM3'
varname = 'FWHM_110'
vardisp = 'PROPERTY: FWHM of 110 peak ($\degree$)'
procdat = pd.DataFrame()

for lib in next(os.walk(cntdir))[1]:
    os.chdir(lib)
    pfname = '_'.join([lib,'AllVar.csv'])
        
    if os.path.exists(pfname):
        #read processed file
        proc = pd.read_csv(pfname)
        procdat = procdat.append(proc,ignore_index=True)
    
    os.chdir(cntdir)

# %%
Bsite = ['Co','Fe','Y','Zr']
compdat = pd.DataFrame(columns=['formula','Co','Fe','Y','Zr','fwhm_110','sample'])
for i in procdat.index:
    try:
        comp = mg.Composition(procdat.loc[i,'FORMULA'])
        compdat.loc[i,'formula'] = procdat.loc[i,'FORMULA']
        compdat.loc[i,'fwhm_110'] = procdat.loc[i,'PROPERTY: FWHM of 110 peak ($\degree$)']
        compdat.loc[i,'sample'] = procdat.loc[i,'IDENTIFIER: Sample number']
        for el in Bsite:
            compdat.loc[i,el] = comp.get_el_amt_dict()[el]
    except Exception: #Sample 1256 has negative Fe amt, just ignore for now
        pass

# %%
procdat[procdat['IDENTIFIER: Sample number']==1502]
# Out:
#                                              FORMULA  IDENTIFIER: Column  \
# 2640   Ba0.83936Co0.65681Fe0.02592Y0.0684Zr0.24886O3                   1
# 2641  Ba0.84811Co0.66947Fe0.02596Y0.06542Zr0.23915O3                   2
# 2642    Ba0.8581Co0.68556Fe0.02375Y0.05678Zr0.2339O3                   3
# 2643  Ba0.84228Co0.68629Fe0.02287Y0.06165Zr0.22919O3                   4
# 2644  Ba0.86095Co0.70163Fe0.02154Y0.05037Zr0.22646O3                   5
# 2645  Ba0.85617Co0.70677Fe0.02152Y0.05193Zr0.21978O3                   6
# 2646   Ba0.86187Co0.71585Fe0.02051Y0.0442Zr0.21944O3                   7
# 2647  Ba0.85214Co0.72223Fe0.01982Y0.04858Zr0.20938O3                   8
# 2648     Ba0.8608Co0.73193Fe0.0183Y0.04587Zr0.2039O3                   9
# 2649   Ba0.85258Co0.73958Fe0.0184Y0.03981Zr0.20221O3                  10
# 2650  Ba0.87377Co0.74606Fe0.02056Y0.03474Zr0.19864O3                  11
# 2651   Ba0.8404Co0.62838Fe0.02708Y0.07841Zr0.26614O3                   1
# 2652  Ba0.82791Co0.64133Fe0.02735Y0.07064Zr0.26068O3                   2
# 2653     Ba0.833Co0.65032Fe0.0266Y0.06922Zr0.25385O3                   3
# 2654  Ba0.83767Co0.65755Fe0.02626Y0.06802Zr0.24818O3                   4
# 2655  Ba0.84198Co0.67109Fe0.02436Y0.05977Zr0.24479O3                   5
# 2656  Ba0.84484Co0.67721Fe0.02573Y0.06119Zr0.23587O3                   6
# 2666                     19.15200
# 2667                     19.15200
# 2668                     19.15200
# 2669                     19.15200
# 2670                     19.15200
# 2671                     19.15200
# 2672                     19.15200
# 2673                      6.65400
# 2674                      6.65400
# 2675                      6.65400
# 2676                      6.65400
# 2677                      6.65400
# 2678                      6.65400
# 2679                      6.65400
# 2680                      6.65400
# 2681                      6.65400
# 2682                      6.65400
# 2683                      6.65400
#
#       PREPARATION STEP DETAIL: Average Target Pulses/Cycle  \
# 2640                                          19.333333
# 2641                                          19.333333
# 2642                                          19.333333
# 2643                                          19.333333
# 2644                                          19.333333
# 2645                                          19.333333
# 2646                                          19.333333
# 2647                                          19.333333
# 2648                                          19.333333
# 2649                                          19.333333
# 2650                                          19.333333
# 2651                                          19.333333
# 2652                                          19.333333
# 2653                                          19.333333
# 2654                                          19.333333
# 2655                                          19.333333
# 2656                                          19.333333
# 2657                                          19.333333
# 2658                                          19.333333
# 2659                                          19.333333
# 2660                                          19.333333
# 2661                                          19.333333
# 2662                                          19.333333
# 2663                                          19.333333
# 2664                                          19.333333
# 2665                                          19.333333
# 2666                                          19.333333
# 2667                                          19.333333
# 2668                                          19.333333
# 2669                                          19.333333
# 2670                                          19.333333
# 2671                                          19.333333
# 2672                                          19.333333
# 2673                                          19.333333
# 2674                                          19.333333
# 2675                                          19.333333
# 2676                                          19.333333
# 2677                                          19.333333
# 2678                                          19.333333
# 2679                                          19.333333
# 2680                                          19.333333
# 2681                                          19.333333
# 2682                                          19.333333
# 2683                                          19.333333
#
#       PREPARATION STEP DETAIL: B12ZY82 Pulses/Cycle  \
# 2640                                              0
# 2641                                              0
# 2642                                              0
# 2643                                              0
# 2644                                              0
# 2645                                              0
# 2646                                              0
# 2647                                              0
# 2648                                              0
# 2649                                              0
# 2650                                              0
# 2651                                              0
# 2652                                              0
# 2653                                              0
# 2654                                              0
# 2655                                              0
# 2656                                              0
# 2657                                              0
# 2658                                              0
# 2659                                              0
# 2660                                              0
# 2661                                              0
# 2662                                              0
# 2663                                              0
# 2664                                              0
# 2665                                              0
# 2666                                              0
# 2667                                              0
# 2668                                              0
# 2669                                              0
# 2670                                              0
# 2671                                              0
# 2672                                              0
# 2673                                              0
# 2674                                              0
# 2675                                              0
# 2676                                              0
# 2677                                              0
# 2678                                              0
# 2679                                              0
# 2680                                              0
# 2681                                              0
# 2682                                              0
# 2683                                              0
#
#                          ...                      \
# 2640                     ...
# 2641                     ...
# 2642                     ...
# 2643                     ...
# 2644                     ...
# 2645                     ...
# 2646                     ...
# 2647                     ...
# 2648                     ...
# 2649                     ...
# 2650                     ...
# 2651                     ...
# 2652                     ...
# 2653                     ...
# 2654                     ...
# 2655                     ...
# 2656                     ...
# 2657                     ...
# 2658                     ...
# 2659                     ...
# 2660                     ...
# 2661                     ...
# 2662                     ...
# 2663                     ...
# 2664                     ...
# 2665                     ...
# 2666                     ...
# 2667                     ...
# 2668                     ...
# 2669                     ...
# 2670                     ...
# 2671                     ...
# 2672                     ...
# 2673                     ...
# 2674                     ...
# 2675                     ...
# 2676                     ...
# 2677                     ...
# 2678                     ...
# 2679                     ...
# 2680                     ...
# 2681                     ...
# 2682                     ...
# 2683                     ...
#
#       PROPERTY: FWHM of 110 peak ($\degree$)  \
# 2640                                0.496568
# 2641                                0.540552
# 2642                                0.498492
# 2643                                0.510050
# 2644                                0.505355
# 2645                                0.522291
# 2646                                0.532232
# 2647                                0.575298
# 2648                                0.476740
# 2649                                0.455009
# 2650                                0.450138
# 2651                                     NaN
# 2652                                     NaN
# 2653                                     NaN
# 2654                                     NaN
# 2655                                0.472805
# 2656                                0.500270
# 2657                                0.520302
# 2658                                0.556234
# 2659                                0.544743
# 2660                                0.489070
# 2661                                0.474062
# 2662                                0.500161
# 2663                                0.527867
# 2664                                0.491914
# 2665                                0.487655
# 2666                                0.491253
# 2667                                0.518174
# 2668                                0.539885
# 2669                                0.576579
# 2670                                0.557221
# 2671                                0.480355
# 2672                                0.482092
# 2673                                0.530900
# 2674                                0.545683
# 2675                                0.603750
# 2676                                0.511038
# 2677                                0.468116
# 2678                                0.464810
# 2679                                0.455483
# 2680                                0.448780
# 2681                                0.440673
# 2682                                0.442075
# 2683                                0.444830
#
#       PROPERTY: FWHM of 111 peak ($\degree$)  \
# 2640                                     NaN
# 2641                                     NaN
# 2642                                     NaN
# 2643                                     NaN
# 2644                                0.500585
# 2645                                0.480079
# 2646                                0.433849
# 2647                                0.443673
# 2648                                0.454612
# 2649                                0.448603
# 2650                                0.391917
# 2651                                     NaN
# 2652                                     NaN
# 2653                                     NaN
# 2654                                     NaN
# 2655                                     NaN
# 2656                                0.569087
# 2657                                0.473703
# 2658                                0.458724
# 2659                                0.429767
# 2660                                0.440364
# 2661                                0.459286
# 2662                                     NaN
# 2663                                     NaN
# 2664                                0.530388
# 2665                                0.456053
# 2666                                0.485817
# 2667                                0.464869
# 2668                                0.428488
# 2669                                0.432078
# 2670                                0.416298
# 2671                                0.450456
# 2672                                0.456058
# 2673                                0.462407
# 2674                                0.430359
# 2675                                0.412377
# 2676                                0.419128
# 2677                                0.430408
# 2678                                0.463188
# 2679                                0.438908
# 2680                                0.435575
# 2681                                0.441716
# 2682                                0.425184
# 2683                                0.453741
#
#       PROPERTY: FWHM of 200 peak ($\degree$)  \
# 2640                                     NaN
# 2641                                     NaN
# 2642                                     NaN
# 2643                                     NaN
# 2644                                     NaN
# 2645                                     NaN
# 2646                                     NaN
# 2647                                     NaN
# 2648                                     NaN
# 2649                                     NaN
# 2650                                     NaN
# 2651                                     NaN
# 2652                                     NaN
# 2653                                     NaN
# 2654                                     NaN
# 2655                                     NaN
# 2656                                     NaN
# 2657                                     NaN
# 2658                                     NaN
# 2659                                     NaN
# 2660                                     NaN
# 2661                                     NaN
# 2662                                     NaN
# 2663                                     NaN
# 2664                                     NaN
# 2665                                     NaN
# 2666                                0.641149
# 2667                                     NaN
# 2668                                     NaN
# 2669                                     NaN
# 2670                                     NaN
# 2671                                     NaN
# 2672                                     NaN
# 2673                                     NaN
# 2674                                     NaN
# 2675                                     NaN
# 2676                                     NaN
# 2677                                     NaN
# 2678                                     NaN
# 2679                                     NaN
# 2680                                     NaN
# 2681                                     NaN
# 2682                                     NaN
# 2683                                     NaN
#
#       PROPERTY: Film thickness ($\mu$m)  \
# 2640                            0.33461
# 2641                            0.36823
# 2642                            0.39534
# 2643                            0.42540
# 2644                            0.44914
# 2645                            0.46675
# 2646                            0.47617
# 2647                            0.47609
# 2648                            0.46343
# 2649                            0.44729
# 2650                            0.41845
# 2651                            0.38351
# 2652                            0.42036
# 2653                            0.45586
# 2654                            0.49008
# 2655                            0.51492
# 2656                            0.53262
# 2657                            0.54101
# 2658                            0.53440
# 2659                            0.51923
# 2660                            0.49022
# 2661                            0.45096
# 2662                            0.36827
# 2663                            0.39834
# 2664                            0.42804
# 2665                            0.45665
# 2666                            0.47794
# 2667                            0.48824
# 2668                            0.49247
# 2669                            0.48111
# 2670                            0.46468
# 2671                            0.43916
# 2672                            0.40666
# 2673                            0.29365
# 2674                            0.31485
# 2675                            0.33582
# 2676                            0.35253
# 2677                            0.36563
# 2678                            0.37584
# 2679                            0.37281
# 2680                            0.36564
# 2681                            0.34896
# 2682                            0.33345
# 2683                            0.30560
#
#       PROPERTY: Max intensity of 110 peak (counts)  \
# 2640                                     494.90240
# 2641                                     363.81610
# 2642                                     464.64215
# 2643                                     826.30310
# 2644                                    1567.61740
# 2645                                    2765.00270
# 2646                                    3501.34110
# 2647                                    3496.65450
# 2648                                    5074.31640
# 2649                                    5298.92870
# 2650                                    4692.69340
# 2651                                           NaN
# 2652                                           NaN
# 2653                                           NaN
# 2654                                           NaN
# 2655                                     537.56244
# 2656                                    1935.90670
# 2657                                    3454.14140
# 2658                                    3973.13820
# 2659                                    4017.42720
# 2660                                    5037.38620
# 2661                                    4933.13770
# 2662                                    1088.46780
# 2663                                    1029.42870
# 2664                                    1409.33110
# 2665                                    2038.42830
# 2666                                    2882.51780
# 2667                                    3486.79250
# 2668                                    3640.57080
# 2669                                    3472.14040
# 2670                                    3606.90230
# 2671                                    4829.28270
# 2672                                    4357.39060
# 2673                                    2345.57420
# 2674                                    2669.14620
# 2675                                    2615.24980
# 2676                                    3621.20950
# 2677                                    4473.31840
# 2678                                    4588.29250
# 2679                                    4629.03120
# 2680                                    4730.46090
# 2681                                    4659.10160
# 2682                                    4293.83980
# 2683                                    3956.88090
#
#       PROPERTY: Max intensity of 111 peak (counts)  \
# 2640                                           NaN
# 2641                                           NaN
# 2642                                           NaN
# 2643                                           NaN
# 2644                                     495.15204
# 2645                                     965.23621
# 2646                                    1769.01530
# 2647                                    2397.32230
# 2648                                    1647.59290
# 2649                                    1543.61890
# 2650                                    1646.29260
# 2651                                           NaN
# 2652                                           NaN
# 2653                                           NaN
# 2654                                           NaN
# 2655                                           NaN
# 2656                                     543.49091
# 2657                                    1395.31670
# 2658                                    2236.08420
# 2659                                    2286.54470
# 2660                                    1749.80370
# 2661                                    1476.60420
# 2662                                           NaN
# 2663                                           NaN
# 2664                                     353.69238
# 2665                                     539.81964
# 2666                                     868.20221
# 2667                                    1441.86540
# 2668                                    1900.79000
# 2669                                    2083.71140
# 2670                                    2026.27580
# 2671                                    1420.10030
# 2672                                    1355.63750
# 2673                                     835.88531
# 2674                                    1215.24340
# 2675                                    1546.00070
# 2676                                    1463.20120
# 2677                                    1278.91940
# 2678                                    1275.80620
# 2679                                    1330.78740
# 2680                                    1253.04610
# 2681                                    1152.14260
# 2682                                    1143.40410
# 2683                                    1005.65510
#
#       PROPERTY: Max intensity of 200 peak (counts)  \
# 2640                                           NaN
# 2641                                           NaN
# 2642                                           NaN
# 2643                                           NaN
# 2644                                           NaN
# 2645                                           NaN
# 2646                                           NaN
# 2647                                           NaN
# 2648                                           NaN
# 2649                                           NaN
# 2650                                           NaN
# 2651                                           NaN
# 2652                                           NaN
# 2653                                           NaN
# 2654                                           NaN
# 2655                                           NaN
# 2656                                           NaN
# 2657                                           NaN
# 2658                                           NaN
# 2659                                           NaN
# 2660                                           NaN
# 2661                                           NaN
# 2662                                           NaN
# 2663                                           NaN
# 2664                                           NaN
# 2665                                           NaN
# 2666                                     300.22684
# 2667                                           NaN
# 2668                                           NaN
# 2669                                           NaN
# 2670                                           NaN
# 2671                                           NaN
# 2672                                           NaN
# 2673                                           NaN
# 2674                                           NaN
# 2675                                           NaN
# 2676                                           NaN
# 2677                                           NaN
# 2678                                           NaN
# 2679                                           NaN
# 2680                                           NaN
# 2681                                           NaN
# 2682                                           NaN
# 2683                                           NaN
#
#       PROPERTY: Position of 110 peak ($\degree$)  \
# 2640                                   30.896833
# 2641                                   30.919537
# 2642                                   30.935024
# 2643                                   30.941521
# 2644                                   30.956699
# 2645                                   30.977461
# 2646                                   30.979757
# 2647                                   30.970547
# 2648                                   30.931026
# 2649                                   30.895227
# 2650                                   30.909094
# 2651                                         NaN
# 2652                                         NaN
# 2653                                         NaN
# 2654                                         NaN
# 2655                                   30.959398
# 2656                                   30.965300
# 2657                                   30.973431
# 2658                                   30.975672
# 2659                                   30.943378
# 2660                                   30.919016
# 2661                                   30.895502
# 2662                                   30.874258
# 2663                                   30.895344
# 2664                                   30.900679
# 2665                                   30.927641
# 2666                                   30.944487
# 2667                                   30.956221
# 2668                                   30.958355
# 2669                                   30.958752
# 2670                                   30.943684
# 2671                                   30.933283
# 2672                                   30.902212
# 2673                                   30.880766
# 2674                                   30.901976
# 2675                                   30.915634
# 2676                                   30.908672
# 2677                                   30.885529
# 2678                                   30.884363
# 2679                                   30.884645
# 2680                                   30.877474
# 2681                                   30.880644
# 2682                                   30.876953
# 2683                                   30.881296
#
#      PROPERTY: Position of 111 peak ($\degree$)  \
# 2640                                        NaN
# 2641                                        NaN
# 2642                                        NaN
# 2643                                        NaN
# 2644                                  38.136093
# 2645                                  38.169003
# 2646                                  38.170090
# 2647                                  38.159977
# 2648                                  38.113258
# 2649                                  38.058586
# 2650                                  38.079395
# 2651                                        NaN
# 2652                                        NaN
# 2653                                        NaN
# 2654                                        NaN
# 2655                                        NaN
# 2656                                  38.156918
# 2657                                  38.169258
# 2658                                  38.165943
# 2659                                  38.137505
# 2660                                  38.092308
# 2661                                  38.065800
# 2662                                        NaN
# 2663                                        NaN
# 2664                                  38.078857
# 2665                                  38.108410
# 2666                                  38.123291
# 2667                                  38.136127
# 2668                                  38.136387
# 2669                                  38.139988
# 2670                                  38.124954
# 2671                                  38.109230
# 2672                                  38.077229
# 2673                                  38.039757
# 2674                                  38.058693
# 2675                                  38.054607
# 2676                                  38.050873
# 2677                                  38.039200
# 2678                                  38.053314
# 2679                                  38.034618
# 2680                                  38.039402
# 2681                                  38.036736
# 2682                                  38.041142
# 2683                                  38.039417
#
#       PROPERTY: Position of 200 peak ($\degree$)
# 2640                                         NaN
# 2641                                         NaN
# 2642                                         NaN
# 2643                                         NaN
# 2644                                         NaN
# 2645                                         NaN
# 2646                                         NaN
# 2647                                         NaN
# 2648                                         NaN
# 2649                                         NaN
# 2650                                         NaN
# 2651                                         NaN
# 2652                                         NaN
# 2653                                         NaN
# 2654                                         NaN
# 2655                                         NaN
# 2656                                         NaN
# 2657                                         NaN
# 2658                                         NaN
# 2659                                         NaN
# 2660                                         NaN
# 2661                                         NaN
# 2662                                         NaN
# 2663                                         NaN
# 2664                                         NaN
# 2665                                         NaN
# 2666                                   44.320232
# 2667                                         NaN
# 2668                                         NaN
# 2669                                         NaN
# 2670                                         NaN
# 2671                                         NaN
# 2672                                         NaN
# 2673                                         NaN
# 2674                                         NaN
# 2675                                         NaN
# 2676                                         NaN
# 2677                                         NaN
# 2678                                         NaN
# 2679                                         NaN
# 2680                                         NaN
# 2681                                         NaN
# 2682                                         NaN
# 2683                                         NaN
#
# [44 rows x 58 columns]

# %%
fig, axes = plt.subplots(2,2,figsize=(14,10))
Y_frac = [0,0.1,0.2,0.3]
full_colors = compdat.loc[:,'fwhm_110'].values

for i, nY in enumerate(Y_frac):
    df = compdat[(compdat['Y']>=nY - 0.05) & (compdat['Y']<nY + 0.05)]
    points = df.loc[:,['Co','Fe','Zr']].values
    colors = df.loc[:,'fwhm_110'].replace(np.nan,10).values
    
    ax=axes[int(i/2), i%2]
    
    scale = 1 - nY #point coords must sum to scale
    #since each comp has different Y value, need to scale points to plot scale
    ptsum = np.sum(points,axis=1)[np.newaxis].T
    scaled_pts = points*scale/ptsum
    
    #tfig, tax = ternary.figure(scale=scale,ax=ax)
    tax = ternary.TernaryAxesSubplot(scale=scale,ax=ax)
    cmap = plt.cm.viridis
    #cmap.set_bad('gray',1.) #doesn't seem to work
    cmap.set_over('darkgray',1.) #make nans grey
    tax.scatter(scaled_pts,s=8,vmin=0.4,vmax=0.7,colormap=cmap,
                colorbar=True,c=colors,cbarlabel='110 FWHM')
    tax.boundary(linewidth=1.0)
    tax.clear_matplotlib_ticks()
    tax.ticks(axis='lbr', linewidth=1, multiple=0.1, tick_formats='%.1f',offset=0.02)
    tax.gridlines(multiple=0.1,linewidth=0.8)
    tax.bottom_axis_label('Co',offset=0.1,fontsize=14, position=(1.05,0.03,0))
    tax.right_axis_label('Fe',offset=0.2,fontsize=14, position=(-0.13,1.25,0), rotation=0)
    tax.left_axis_label('Zr',offset=0.2,fontsize=14, position=(-0.10,0.03,1), rotation=0)
    tax.set_title('{0:.2f} $\leq$ Y < {1:.2f}'.format(max(0,nY-0.05),min(nY+0.05,0.3)),fontsize=13,x=0.15,y=0.9)
    tax._redraw_labels()
    ax.axis('off')
        
plt.suptitle('Experimental 110 FWHM vs. B-Site Composition',size=14,y=0.95)
#ternary.colormapping.colorbar_hack(ax=axes, vmin=0.4,vmax=0.7,cmap=cmap,cbarlabel='110 FWHM')
#fig.subplots_adjust(wspace=0.3)
#plt.savefig(os.path.join(scriptdir,'plots','Bsite_fwhm110_ternary_exp.png'),dpi=350)
# Out:
# Text(0.5,0.95,'Experimental 110 FWHM vs. B-Site Composition')

# %%
fig, axes = plt.subplots(2,2,figsize=(12,10))
Y_frac = [0,0.1,0.2,0.3]
full_colors = compdat.loc[:,'fwhm_110'].values
vmin = 0.4
vmax = 0.7
ignore = [1502,1503,1505]

for i, nY in enumerate(Y_frac):
    df = compdat[(compdat['Y']>=nY - 0.05) & (compdat['Y']<nY + 0.05) & (compdat['sample'].isin(ignore)==False)]
    points = df.loc[:,['Co','Fe','Zr']].values
    colors = df.loc[:,'fwhm_110'].replace(np.nan,10).values
    
    ax=axes[int(i/2), i%2]
    
    scale = 1 - nY #point coords must sum to scale
    #since each comp has different Y value, need to scale points to plot scale
    ptsum = np.sum(points,axis=1)[np.newaxis].T
    scaled_pts = points*scale/ptsum
    
    #tfig, tax = ternary.figure(scale=scale,ax=ax)
    tax = ternary.TernaryAxesSubplot(scale=scale,ax=ax)
    cmap = plt.cm.viridis
    #cmap.set_bad('gray',1.) #doesn't seem to work
    cmap.set_over('darkgray',1.) #make nans grey
    tax.scatter(scaled_pts,s=8,vmin=vmin,vmax=vmax,colormap=cmap,
                colorbar=False,c=colors)
    tax.boundary(linewidth=1.0)
    tax.clear_matplotlib_ticks()
    tax.ticks(axis='lbr', linewidth=1, multiple=0.1, tick_formats='%.1f',offset=0.03)
    tax.gridlines(multiple=0.1,linewidth=0.8)
    tax.bottom_axis_label('Co',offset=0.1,fontsize=14, position=(1.05,0.03,0))
    tax.right_axis_label('Fe',offset=0.2,fontsize=14, position=(-0.13,1.25,0), rotation=0)
    tax.left_axis_label('Zr',offset=0.2,fontsize=14, position=(-0.10,0.03,1), rotation=0)
    
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    tax.set_title('{0:.2f} $\leq$ Y < {1:.2f}'.format(max(0,nY-0.05),min(nY+0.05,0.3)),fontsize=14,x=0.13,y=0.97, bbox=props)
    tax._redraw_labels()
    ax.axis('off')
        
plt.suptitle('Experimental 110 FWHM vs. B-Site Composition',size=16,y=0.97)

#add a single colorbar
#make an axis for colorbar to control position/size
cbaxes = fig.add_axes([0.9,0.15,0.02,0.75]) #[left, bottom, width, height]
#code from colormapping.colorbar_hack
norm = plt.Normalize(vmin=vmin, vmax=vmax)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
s
# 1581  Ba0.68752Co0.0Fe0.06577Y0.29217Zr0.64206O3  0  0.06577  0.29217
# 1582  Ba0.68771Co0.0Fe0.06673Y0.29246Zr0.64081O3  0  0.06673  0.29246
# 1583  Ba0.70454Co0.0Fe0.06682Y0.28916Zr0.64402O3  0  0.06682  0.28916
#
#            Zr  fwhm_110
# 0     0.65192       NaN
# 1     0.64532       NaN
# 2     0.65087       NaN
# 3     0.64798       NaN
# 4     0.65636       NaN
# 5     0.65354       NaN
# 6     0.64065       NaN
# 7     0.63849       NaN
# 8     0.64366       NaN
# 9     0.62058       NaN
# 10    0.56645       NaN
# 11     0.6589       NaN
# 12    0.65136       NaN
# 13    0.64891       NaN
# 14    0.65292       NaN
# 15    0.65206       NaN
# 16    0.64213       NaN
# 17    0.64787       NaN
# 18    0.65389       NaN
# 19    0.63999       NaN
# 20    0.62606       NaN
# 21    0.58332       NaN
# 22    0.64291       NaN
# 23    0.65169       NaN
# 24    0.64868       NaN
# 25    0.64917       NaN
# 26    0.65876       NaN
# 27    0.64495       NaN
# 28    0.64169       NaN
# 29    0.65263       NaN
# ...       ...       ...
# 1554  0.64207  0.479154
# 1555  0.64358  0.481044
# 1556  0.64095  0.490231
# 1557  0.64188  0.500079
# 1558  0.64007  0.489369
# 1559  0.63675  0.498221
# 1560  0.63545  0.501186
# 1561  0.63336  0.533689
# 1562  0.64105  0.477117
# 1563  0.64126  0.480404
# 1564  0.63543  0.479521
# 1565  0.63981  0.499959
# 1566  0.64309  0.511634
# 1567  0.64083   0.51721
# 1568  0.64178  0.513647
# 1569  0.64094  0.523991
# 1570  0.64131  0.526954
# 1571  0.63615  0.532463
# 1572  0.64373  0.543967
# 1573  0.63566   0.47598
# 1574   0.6384  0.476157
# 1575  0.63702  0.481513
# 1576  0.63541  0.495811
# 1577  0.63662   0.53036
# 1578  0.63973  0.545799
# 1579  0.64034  0.560604
# 1580    0.642  0.564501
# 1581  0.64206  0.578022
# 1582  0.64081  0.559728
# 1583  0.64402  0.578931
#
# [144 rows x 6 columns]

# %%
fig, axes = plt.subplots(2,2,figsize=(12,10))
Y_frac = [0,0.1,0.2,0.3]
full_colors = compdat.loc[:,'fwhm_110'].values

for i, nY in enumerate(Y_frac):
    df = compdat[(compdat['Y']>=nY - 0.05) & (compdat['Y']<nY + 0.05)]
    points = df.loc[:,['Co','Fe','Zr']].values
    colors = df.loc[:,'fwhm_110'].replace(np.nan,10).values
    
    ax=axes[int(i/2), i%2]
    
    scale = 1 - nY #point coords must sum to scale
    #since each comp has different Y value, need to scale points to plot scale
    ptsum = np.sum(points,axis=1)[np.newaxis].T
    scaled_pts = points*scale/ptsum
    
    tfig, tax = ternary.figure(scale=scale,ax=ax)
    cmap = plt.cm.viridis
    #cmap.set_bad('gray',1.) #doesn't seem to work
    cmap.set_over('darkgray',1.) #make nans grey
    tax.scatter(scaled_pts,s=8,vmin=0.4,vmax=0.7,colormap=cmap,
                colorbar=True,c=colors, cbarlabel='110 FWHM')
    tax.boundary(linewidth=1.0)
    tax.clear_matplotlib_ticks()
    tax.ticks(axis='lbr', linewidth=1, multiple=0.1, tick_formats='%.1f',offset=0.02)
    tax.gridlines(multiple=0.1,linewidth=0.8)
    tax.bottom_axis_label('Co',offset=0.1,fontsize=12)
    tax.right_axis_label('Fe',offset=0.2,fontsize=12)
    tax.left_axis_label('Zr',offset=0.2,fontsize=12)
    tax.set_title('{0:.2f} $\leq$ Y < {1:.2f}'.format(max(0,nY-0.05),min(nY+0.05,0.3)),fontsize=13,x=0.15,y=0.9)
    tax._redraw_labels()
    ax.axis('off')
    
    #add marker for recommended test composition
    if nY == 0.1:
        coord = (0.7,0.1,0.1)
        tax.scatter([coord],s=50,c='r',marker='o')
        tax.annotate('Test composition',position=coord, 
                     xytext = (0.76,-0.18), fontsize=12, horizontalalignment='center', verticalalignment='center',
                     bbox=dict(boxstyle='square',fc='white'),
                     arrowprops=dict(facecolor='k',shrink=0.1,width = 2,headwidth=8))
        
plt.suptitle('Experimental 110 FWHM vs. B-Site Composition',size=14,y=0.95)
plt.savefig(os.path.join(scriptdir,'plots','Bsite_fwhm110_ternary_exp_annotated.png'),dpi=350)

# %%
for i in compdat.index:
    comp = mg.Composition(compdat.loc[i,'formula'])
    compdat.loc[i,'Ba'] = comp.get_el_amt_dict()['Ba']

# %%
compdat['Ba'].min(), compdat['Ba'].max(), compdat['Ba'].mean()
# Out:
# (0.46018, 1.0, 0.8583618041634551)

# %%
compdat['Ba'].hist()

# %%
procdat.plot('PREPARATION STEP DETAIL: Average Target Pulses/Cycle','PREPARATION STEP DETAIL: Number of Cycles', ls='',marker='.')

# %%
procdat['Total Pulses'] = procdat['PREPARATION STEP DETAIL: Average Target Pulses/Cycle']*procdat['PREPARATION STEP DETAIL: Number of Cycles']

# %%
procdat['Total Pulses'].hist()

# %%
for sub in procdat['PREPARATION STEP DETAIL: Substrate'].unique():
    print (sub, len(procdat[procdat['PREPARATION STEP DETAIL: Substrate']==sub]))
# Out:
# EXG 748
# SiO2 1760
# ITO/EXG 132

# %%
procdat['PREPARATION STEP DETAIL: Temperature ($^{\circ}$C)'].hist()
plt.show()
procdat['PREPARATION STEP DETAIL: Laser Energy (mJ)'].hist()

# %%
procdat[procdat['PREPARATION STEP DETAIL: Average Target Pulses/Cycle']<=500]['PREPARATION STEP DETAIL: Average Target Pulses/Cycle'].hist()

# %%
procdat['PREPARATION STEP DETAIL: Substrate'].unique()
# Out:
# array(['EXG', 'SiO2', 'ITO/EXG'], dtype=object)

# %%
procdat.iloc[0,:]
# Out:
# FORMULA                                                 Ba0.8306Co0.0Fe0.05998Y0.2881Zr0.65192O3
# IDENTIFIER: Column                                                                             1
# IDENTIFIER: Date                                                                      9_Feb_2016
# IDENTIFIER: Point                                                                              1
# IDENTIFIER: Row                                                                                1
# IDENTIFIER: Sample number                                                                   1023
# IDENTIFIER: X position (mm)                                                                  5.4
# IDENTIFIER: Y position (mm)                                                               44.142
# PREPARATION STEP DETAIL: Average Target Pulses/Cycle                                        1000
# PREPARATION STEP DETAIL: B12ZY82 Pulses/Cycle                                                  0
# PREPARATION STEP DETAIL: B12ZY82 Substrate Angle                                               0
# PREPARATION STEP DETAIL: BZC19 Pulses/Cycle                                                    0
# PREPARATION STEP DETAIL: BZC19 Substrate Angle                                                 0
# PREPARATION STEP DETAIL: BZC91 Pulses/Cycle                                                    0
# PREPARATION STEP DETAIL: BZC91 Substrate Angle                                                 0
# PREPARATION STEP DETAIL: BZF19 Pulses/Cycle                                                    0
# PREPARATION STEP DETAIL: BZF19 Substrate Angle                                                 0
# PREPARATION STEP DETAIL: BZY82 Pulses/Cycle                                                    0
# PREPARATION STEP DETAIL: BZY82 Substrate Angle                                                 0
# PREPARATION STEP DETAIL: BZYCF1135 Pulses/Cycle                                                0
# PREPARATION STEP DETAIL: BZYCF1135 Substrate Angle                                             0
# PREPARATION STEP DETAIL: BZYF631 Pulses/Cycle                                               1000
# PREPARATION STEP DETAIL: BZYF631 Substrate Angle                                              45
# PREPARATION STEP DETAIL: Deposition Pressure (mTorr)                                          50
# PREPARATION STEP DETAIL: Laser Energy (mJ)                                                   400
# PREPARATION STEP DETAIL: Laser Pulse Frequency                                                10
# PREPARATION STEP DETAIL: Laser Voltage (kV)                                                   18
# PREPARATION STEP DETAIL: Number of Cycles                                                     10
# PREPARATION STEP DETAIL: Substrate                                                           EXG
# PREPARATION STEP DETAIL: Targets used                                                    BZYF631
# PREPARATION STEP DETAIL: Temperature ($^{\circ}$C)                                           800
# PREPARATION STEP DETAIL: Temperature Gradient                                                  Y
# PREPARATION STEP NAME                                                    Pulsed Laser Deposition
# PROPERTY: AB_X_ratio                                                                     0.67003
# PROPERTY: AB_at_radius_ratio                                                              1.3329
# PROPERTY: AB_ion_radius_ratio                                                            1.63483
# PROPERTY: AB_mass_ratio                                                                  1.55288
# PROPERTY: AB_site_ratio                                                                 0.830599
# PROPERTY: A_avg_X                                                                       0.890001
# PROPERTY: A_avg_at_radius                                                                   2.15
# PROPERTY: A_avg_ion_radius                                                                  1.49
# PROPERTY: A_avg_mass                                                                     137.327
# PROPERTY: Area of 110 peak                                                                   NaN
# PROPERTY: B_avg_X                                                                         1.3283
# PROPERTY: B_avg_at_radius                                                                1.61303
# PROPERTY: B_avg_ion_radius                                                              0.911408
# PROPERTY: B_avg_mass                                                                     88.4341
# PROPERTY: Cubic lattice constant ($\r{A}$)                                                   NaN
# PROPERTY: FWHM of 110 peak ($\degree$)                                                       NaN
# PROPERTY: FWHM of 111 peak ($\degree$)                                                       NaN
# PROPERTY: FWHM of 200 peak ($\degree$)                                                       NaN
# PROPERTY: Film thickness ($\mu$m)                                                        0.08615
# PROPERTY: Max intensity of 110 peak (counts)                                                 NaN
# PROPERTY: Max intensity of 111 peak (counts)                                                 NaN
# PROPERTY: Max intensity of 200 peak (counts)                                                 NaN
# PROPERTY: Position of 110 peak ($\degree$)                                                   NaN
# PROPERTY: Position of 111 peak ($\degree$)                                                   NaN
# PROPERTY: Position of 200 peak ($\degree$)                                                   NaN
# Name: 0, dtype: object
