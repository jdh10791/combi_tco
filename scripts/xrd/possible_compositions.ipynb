# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import pymatgen as mg
import ternary
import pypyodbc as odbc

# %%
#simple test
targets = ['A','B','C']
target_fracs = pd.DataFrame(columns=targets)
for x1 in frac:
    for x2 in frac:
        x3 = 1 - (x1 + x2)
        if x3 >= 0:
            target_fracs = target_fracs.append(pd.Series([x1,x2,x3],index=targets),ignore_index=True)
target_fracs.to_csv('method1.csv')

# %%
targets = ['BaZr0.1Fe0.9O3',
    'BaZr0.1Co0.9O3',
    'BaZr0.9Co0.1O3',
    'BaZr0.6Y0.3Fe0.1O3',
    'BaZr0.1Y0.1Fe0.3Co0.5O3',
    'BaZr0.8Y0.2O3']

dx = 0.1
frac = np.arange(0, 1+dx, dx)

tarcomp = {}
for t in targets:
    tc = mg.Composition(t)
    tarcomp[t] = tc.get_el_amt_dict()

Bsite = ['Co','Fe','Y','Zr']


fkey = np.zeros(len(frac))
fracdf = pd.DataFrame({'key':fkey,'frac':frac})

target_frac = pd.DataFrame({'key':0},index=[0])
for t in targets:
    tdf = fracdf.rename(columns={'frac':t})
    target_frac = pd.merge(target_frac,tdf,on='key')

target_frac['frac_sum'] = target_frac[targets].sum(axis=1)
target_frac = target_frac[target_frac['frac_sum'].round(5)==1]

for el in Bsite:
    target_frac.insert(len(target_frac.columns),el,0)

for t in targets:
    td = tarcomp[t]
    for el in Bsite:
        amt = td[el]
        for i in target_frac.index:
            target_frac.loc[i,el] += amt*target_frac.loc[i,t]

# %%
bsum = target_frac[Bsite].sum(axis=1)
bsum[bsum.round(5)!=1]
# Out:
# Series([], dtype: float64)

# %%
target_frac.Y.hist(bins=np.arange(0,0.325,0.025))

# %%
fig, axes = plt.subplots(2,2,figsize=(12,10))
dY = 0.1
Y_frac = np.arange(0,0.31,dY)
for i, nY in enumerate(Y_frac):
    df = target_frac[(target_frac['Y']>=nY-dY/2) & (target_frac['Y']<=nY+dY/2)]
    points = df.loc[:,['Co','Fe','Zr']].values
    #colors = df.loc[:,'fwhm_110'].values
    
    ax=axes[int(i/2), i%2]
    
    scale = 1 - nY #point coords must sum to scale
    #since each comp has different Y value, need to scale points to plot scale
    ptsum = np.sum(points,axis=1)[np.newaxis].T
    scaled_pts = points*scale/ptsum
    
    tfig, tax = ternary.figure(scale=scale,ax=ax)
    tax.scatter(scaled_pts,s=1)
                #,vmin=0.45,vmax=0.6,colormap=plt.cm.viridis,
                #colorbar=True,c=colors, cbarlabel='Predicted 110 FWHM')
    tax.boundary(linewidth=1.0)
    tax.clear_matplotlib_ticks()
    tax.ticks(axis='lbr', linewidth=1, multiple=scale/10, tick_formats='%.3f',offset=0.02)
    tax.gridlines(multiple=scale/10,linewidth=0.8)
    tax.bottom_axis_label('Co',offset=0.1,fontsize=12)
    tax.right_axis_label('Fe',offset=0.2,fontsize=12)
    tax.left_axis_label('Zr',offset=0.2,fontsize=12)
    tax.set_title('{0:.2f} $\leq$ Y < {1:.2f}'.format(max(0,nY-dY/2),min(nY+dY/2,0.3)),fontsize=13,x=0.15,y=0.9)
    tax._redraw_labels()
    ax.axis('off')

# %%
df
# Out:
#        key  BaZr0.1Fe0.9O3  BaZr0.1Co0.9O3  BaZr0.9Co0.1O3  \
# 730      0             0.0             0.0             0.0
# 740      0             0.0             0.0             0.0
# 850      0             0.0             0.0             0.0
# 860      0             0.0             0.0             0.0
# 870      0             0.0             0.0             0.0
# 970      0             0.0             0.0             0.0
# 980      0             0.0             0.0             0.0
# 990      0             0.0             0.0             0.0
# 1090     0             0.0             0.0             0.0
# 1100     0             0.0             0.0             0.0
# 1210     0             0.0             0.0             0.0
# 2300     0             0.0             0.0             0.1
# 2420     0             0.0             0.0             0.1
# 15610    0             0.0             0.1             0.0
# 15730    0             0.0             0.1             0.0
# 162020   0             0.1             0.0             0.0
# 162140   0             0.1             0.0             0.0
#
#         BaZr0.6Y0.3Fe0.1O3  BaZr0.1Y0.1Fe0.3Co0.5O3  BaZr0.8Y0.2O3  frac_sum  \
# 730                    0.6                      0.0            0.4       1.0
# 740                    0.6                      0.1            0.3       1.0
# 850                    0.7                      0.0            0.3       1.0
# 860                    0.7                      0.1            0.2       1.0
# 870                    0.7                      0.2            0.1       1.0
# 970                    0.8                      0.0            0.2       1.0
# 980                    0.8                      0.1            0.1       1.0
# 990                    0.8                      0.2            0.0       1.0
# 1090                   0.9                      0.0            0.1       1.0
# 1100                   0.9                      0.1            0.0       1.0
# 1210                   1.0                      0.0            0.0       1.0
# 2300                   0.8                      0.0            0.1       1.0
# 2420                   0.9                      0.0            0.0       1.0
# 15610                  0.8                      0.0            0.1       1.0
# 15730                  0.9                      0.0            0.0       1.0
# 162020                 0.8                      0.0            0.1       1.0
# 162140                 0.9                      0.0            0.0       1.0
#
#           Co    Fe     Y    Zr
# 730     0.00  0.06  0.26  0.68
# 740     0.05  0.09  0.25  0.61
# 850     0.00  0.07  0.27  0.66
# 860     0.05  0.10  0.26  0.59
# 870     0.10  0.13  0.25  0.52
# 970     0.00  0.08  0.28  0.64
# 980     0.05  0.11  0.27  0.57
# 990     0.10  0.14  0.26  0.50
# 1090    0.00  0.09  0.29  0.62
# 1100    0.05  0.12  0.28  0.55
# 1210    0.00  0.10  0.30  0.60
# 2300    0.01  0.08  0.26  0.65
# 2420    0.01  0.09  0.27  0.63
# 15610   0.09  0.08  0.26  0.57
# 15730   0.09  0.09  0.27  0.55
# 162020  0.00  0.17  0.26  0.57
# 162140  0.00  0.18  0.27  0.55

# %%
conn = odbc.connect("DRIVER={SQL Server};SERVER=MME-DESKTOP24\SQLEXPRESS01;Trusted_Connection=yes;DATABASE=Test")

# %%
cur = conn.cursor()
cur.execute('select * from TargetFractions')
results = cur.fetchall()

targets = ['BaZr0.1Fe0.9O3',
    'BaZr0.1Co0.9O3',
    'BaZr0.9Co0.1O3',
    'BaZr0.6Y0.3Fe0.1O3',
    'BaZr0.1Y0.1Fe0.3Co0.5O3',
    'BaZr0.8Y0.2O3']

tarcomp = {}
for t in targets:
    tc = mg.Composition(t)
    tarcomp[t] = tc.get_el_amt_dict()

Bsite = ['Co','Fe','Y','Zr']

target_frac = pd.DataFrame(results, columns=targets + ['FracSum','Co','Fe','Y','Zr'])
target_frac
# Out:
#          BaZr0.1Fe0.9O3  BaZr0.1Co0.9O3  BaZr0.9Co0.1O3  BaZr0.6Y0.3Fe0.1O3  \
# 9                          0.700          0.025      1.0  0.4625  0.3450
# 10                         0.725          0.000      1.0  0.4750  0.3525
# 11                         0.000          0.700      1.0  0.1125  0.1375
# 12                         0.025          0.675      1.0  0.1250  0.1450
# 13                         0.050          0.650      1.0  0.1375  0.1525
# 14                         0.075          0.625      1.0  0.1500  0.1600
# 15                         0.100          0.600      1.0  0.1625  0.1675
# 16                         0.125          0.575      1.0  0.1750  0.1750
# 17                         0.150          0.550      1.0  0.1875  0.1825
# 18                         0.175          0.525      1.0  0.2000  0.1900
# 19                         0.200          0.500      1.0  0.2125  0.1975
# 20                         0.225          0.475      1.0  0.2250  0.2050
# 21                         0.250          0.450      1.0  0.2375  0.2125
# 22                         0.275          0.425      1.0  0.2500  0.2200
# 23                         0.300          0.400      1.0  0.2625  0.2275
# 24                         0.325          0.375      1.0  0.2750  0.2350
# 25                         0.350          0.350      1.0  0.2875  0.2425
# 26                         0.375          0.325      1.0  0.3000  0.2500
# 27                         0.400          0.300      1.0  0.3125  0.2575
# 28                         0.425          0.275      1.0  0.3250  0.2650
# 29                         0.450          0.250      1.0  0.3375  0.2725
# ...                          ...            ...      ...     ...     ...
# 1077285                    0.000          0.025      1.0  0.8350  0.0225
# 1077286                    0.025          0.000      1.0  0.8475  0.0300
# 1077287                    0.000          0.000      1.0  0.8350  0.0250
# 1077288                    0.000          0.000      1.0  0.8375  0.0225
# 1077289                    0.000          0.025      1.0  0.8325  0.0450
# 1077290                    0.025          0.000      1.0  0.8450  0.0525
# 1077291                    0.000          0.000      1.0  0.8325  0.0475
# 1077292                    0.000          0.000      1.0  0.8350  0.0450
# 1077293                    0.000          0.000      1.0  0.8325  0.0675
# 1077294                    0.000          0.050      1.0  0.8550  0.0000
# 1077295                    0.025          0.025      1.0  0.8675  0.0075
# 1077296                    0.050          0.000      1.0  0.8800  0.0150
# 1077297                    0.000          0.025      1.0  0.8550  0.0025
# 1077298                    0.025          0.000      1.0  0.8675  0.0100
# 1077299                    0.000          0.000      1.0  0.8550  0.0050
# 1077300                    0.000          0.025      1.0  0.8575  0.0000
# 1077301                    0.025          0.000      1.0  0.8700  0.0075
# 1077302                    0.000          0.000      1.0  0.8575  0.0025
# 1077303                    0.000          0.000      1.0  0.8600  0.0000
# 1077304                    0.000          0.025      1.0  0.8550  0.0225
# 1077305                    0.025          0.000      1.0  0.8675  0.0300
# 1077306                    0.000          0.000      1.0  0.8550  0.0250
# 1077307                    0.000          0.000      1.0  0.8575  0.0225
# 1077308                    0.000          0.000      1.0  0.8550  0.0450
# 1077309                    0.000          0.025      1.0  0.8775  0.0000
# 1077310                    0.025          0.000      1.0  0.8900  0.0075
# 1077311                    0.000          0.000      1.0  0.8775  0.0025
# 1077312                    0.000          0.000      1.0  0.8800  0.0000
# 1077313                    0.000          0.000      1.0  0.8775  0.0225
# 1077314                    0.000          0.000      1.0  0.9000  0.0000
#
#               Y      Zr
# 0        0.0975  0.2750
# 1        0.0950  0.2575
# 2        0.0925  0.2400
# 3        0.0900  0.2225
# 4        0.0875  0.2050
# 5        0.0850  0.1875
# 6        0.0825  0.1700
# 7        0.0800  0.1525
# 8        0.0775  0.1350
# 9        0.0750  0.1175
# 10       0.0725  0.1000
# 11       0.1475  0.6025
# 12       0.1450  0.5850
# 13       0.1425  0.5675
# 14       0.1400  0.5500
# 15       0.1375  0.5325
# 16       0.1350  0.5150
# 17       0.1325  0.4975
# 18       0.1300  0.4800
# 19       0.1275  0.4625
# 20       0.1250  0.4450
# 21       0.1225  0.4275
# 22       0.1200  0.4100
# 23       0.1175  0.3925
# 24       0.1150  0.3750
# 25       0.1125  0.3575
# 26       0.1100  0.3400
# 27       0.1075  0.3225
# 28       0.1050  0.3050
# 29       0.1025  0.2875
# ...         ...     ...
# 1077285  0.0050  0.1375
# 1077286  0.0025  0.1200
# 1077287  0.0075  0.1325
# 1077288  0.0000  0.1400
# 1077289  0.0050  0.1175
# 1077290  0.0025  0.1000
# 1077291  0.0075  0.1125
# 1077292  0.0000  0.1200
# 1077293  0.0000  0.1000
# 1077294  0.0100  0.1350
# 1077295  0.0075  0.1175
# 1077296  0.0050  0.1000
# 1077297  0.0125  0.1300
# 1077298  0.0100  0.1125
# 1077299  0.0150  0.1250
# 1077300  0.0050  0.1375
# 1077301  0.0025  0.1200
# 1077302  0.0075  0.1325
# 1077303  0.0000  0.1400
# 1077304  0.0050  0.1175
# 1077305  0.0025  0.1000
# 1077306  0.0075  0.1125
# 1077307  0.0000  0.1200
# 1077308  0.0000  0.1000
# 1077309  0.0050  0.1175
# 1077310  0.0025  0.1000
# 1077311  0.0075  0.1125
# 1077312  0.0000  0.1200
# 1077313  0.0000  0.1000
# 1077314  0.0000  0.1000
#
# [1077315 rows x 11 columns]

# %%
fig, axes = plt.subplots(2,2,figsize=(12,10))
dY = 0.1
Y_frac = np.arange(0,0.31,dY)
for i, nY in enumerate(Y_frac):
    df = target_frac[(target_frac['Y']>=nY-dY/2) & (target_frac['Y']<=nY+dY/2)]
    points = df.loc[:,['Co','Fe','Zr']].values
    #colors = df.loc[:,'fwhm_110'].values
    
    ax=axes[int(i/2), i%2]
    
    scale = 1 - nY #point coords must sum to scale
    #since each comp has different Y value, need to scale points to plot scale
    ptsum = np.sum(points,axis=1)[np.newaxis].T
    scaled_pts = points*scale/ptsum
    
    tfig, tax = ternary.figure(scale=scale,ax=ax)
    tax.scatter(scaled_pts,s=0.5)
                #,vmin=0.45,vmax=0.6,colormap=plt.cm.viridis,
                #colorbar=True,c=colors, cbarlabel='Predicted 110 FWHM')
    tax.boundary(linewidth=1.0)
    tax.clear_matplotlib_ticks()
    tax.ticks(axis='lbr', linewidth=1, multiple=scale/10, tick_formats='%.2f',offset=0.03)
    tax.gridlines(multiple=scale/10,linewidth=0.8)
    tax.bottom_axis_label('Co',offset=0.1,fontsize=12)
    tax.right_axis_label('Fe',offset=0.2,fontsize=12)
    tax.left_axis_label('Zr',offset=0.2,fontsize=12)
    tax.set_title('{0:.2f} $\leq$ Y < {1:.2f}'.format(max(0,nY-dY/2),min(nY+dY/2,0.3)),fontsize=13,x=0.15,y=0.9)
    tax._redraw_labels()
    ax.axis('off')

# %%
target_frac['BaZr0.1Fe0.9O3'][0]
# Out:
# 0.0

# %%
len(results)
# Out:
# 230230
